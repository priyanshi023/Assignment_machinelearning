# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("C:/Users/PC-LENOVO/Documents/Machine Learning/new sir/obesity.csv")
data.tail()
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 53387       2016     2016           VI  Virgin Islands
# 53388       2016     2016           VI  Virgin Islands
# 53389       2016     2016           VI  Virgin Islands
# 53390       2016     2016           VI  Virgin Islands
# 53391       2016     2016           VI  Virgin Islands
#
#                                        Datasource              Class  \
# 53387  Behavioral Risk Factor Surveillance System  Physical Activity
# 53388  Behavioral Risk Factor Surveillance System  Physical Activity
# 53389  Behavioral Risk Factor Surveillance System  Physical Activity
# 53390  Behavioral Risk Factor Surveillance System  Physical Activity
# 53391  Behavioral Risk Factor Surveillance System  Physical Activity
#
#                               Topic  \
# 53387  Physical Activity - Behavior
# 53388  Physical Activity - Behavior
# 53389  Physical Activity - Behavior
# 53390  Physical Activity - Behavior
# ...

# %%
data.shape
# Out:
# (53392, 33)

# %%
data.isnull().sum()/len(data) * 100
# Out:
# YearStart                       0.000000
# YearEnd                         0.000000
# LocationAbbr                    0.000000
# LocationDesc                    0.000000
# Datasource                      0.000000
# Class                           0.000000
# Topic                           0.000000
# Question                        0.000000
# Data_Value_Unit               100.000000
# Data_Value_Type                 0.000000
# Data_Value                      9.450854
# Data_Value_Alt                  9.450854
# Data_Value_Footnote_Symbol     90.549146
# Data_Value_Footnote            90.549146
# Low_Confidence_Limit            9.450854
# High_Confidence_Limit           9.450854
# Sample_Size                     9.450854
# Total                          96.428304
# Age(years)                     78.577315
# Education                      85.713215
# Gender                         92.856608
# Income                         74.998127
# Race/Ethnicity                 71.426431
# ...

# %% [markdown]
# #### here the missing data is given in percentage and hence we can remove unnecessary data.

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# ##### Missing Value imputation

# %%
data.drop(['LocationAbbr','Data_Value_Unit','Data_Value_Footnote_Symbol','Data_Value_Footnote','Total','Age(years)','Education','Gender','Income','Race/Ethnicity'] , axis=1, inplace=True)
data
# Out:
#        YearStart  YearEnd    LocationDesc  \
# 0           2011     2011         Alabama
# 1           2011     2011         Alabama
# 2           2011     2011         Alabama
# 3           2011     2011         Alabama
# 4           2011     2011         Alabama
# ...          ...      ...             ...
# 53387       2016     2016  Virgin Islands
# 53388       2016     2016  Virgin Islands
# 53389       2016     2016  Virgin Islands
# 53390       2016     2016  Virgin Islands
# 53391       2016     2016  Virgin Islands
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...

# %%
data.dropna(how='any', inplace=True)
data.head()
# Out:
#    YearStart  YearEnd LocationDesc  \
# 0       2011     2011      Alabama
# 1       2011     2011      Alabama
# 2       2011     2011      Alabama
# 3       2011     2011      Alabama
# 4       2011     2011      Alabama
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                      Topic                                           Question  \
# 0  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 1  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 2  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# ...

# %%
data.shape
# Out:
# (47338, 23)

# %%
data.isnull().sum()/len(data) * 100
# Out:
# YearStart                    0.0
# YearEnd                      0.0
# LocationDesc                 0.0
# Datasource                   0.0
# Class                        0.0
# Topic                        0.0
# Question                     0.0
# Data_Value_Type              0.0
# Data_Value                   0.0
# Data_Value_Alt               0.0
# Low_Confidence_Limit         0.0
# High_Confidence_Limit        0.0
# Sample_Size                  0.0
# GeoLocation                  0.0
# ClassID                      0.0
# TopicID                      0.0
# QuestionID                   0.0
# DataValueTypeID              0.0
# LocationID                   0.0
# StratificationCategory1      0.0
# Stratification1              0.0
# StratificationCategoryId1    0.0
# StratificationID1            0.0
# dtype: float64

# %% [markdown]
# #### Encoding

# %%
data1=pd.get_dummies(data[['LocationDesc','DataValueTypeID','Datasource','Class','Topic','Question','ClassID','TopicID','Data_Value_Type','StratificationCategory1','Stratification1','StratificationCategoryId1','StratificationID1']], drop_first=True)
data1
# Out:
#        LocationDesc_Alaska  LocationDesc_Arizona  LocationDesc_Arkansas  \
# 0                        0                     0                      0
# 1                        0                     0                      0
# 2                        0                     0                      0
# 3                        0                     0                      0
# 4                        0                     0                      0
# ...                    ...                   ...                    ...
# 53382                    0                     0                      0
# 53383                    0                     0                      0
# 53384                    0                     0                      0
# 53385                    0                     0                      0
# 53386                    0                     0                      0
#
#        LocationDesc_California  LocationDesc_Colorado  \
# ...

# %%
data2=pd.concat([data,data1], axis=1)
data2
# Out:
#        YearStart  YearEnd    LocationDesc  \
# 0           2011     2011         Alabama
# 1           2011     2011         Alabama
# 2           2011     2011         Alabama
# 3           2011     2011         Alabama
# 4           2011     2011         Alabama
# ...          ...      ...             ...
# 53382       2016     2016  Virgin Islands
# 53383       2016     2016  Virgin Islands
# 53384       2016     2016  Virgin Islands
# 53385       2016     2016  Virgin Islands
# 53386       2016     2016  Virgin Islands
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...

# %%
datanew=data2.drop(['LocationDesc','Datasource','Class','Topic','DataValueTypeID','Question','ClassID','TopicID','Data_Value_Type','StratificationCategory1','Stratification1','StratificationCategoryId1','StratificationID1'], axis=1)
datanew
# Out:
#        YearStart  YearEnd  Data_Value  Data_Value_Alt  Low_Confidence_Limit  \
# 0           2011     2011        32.0            32.0                  30.5
# 1           2011     2011        32.3            32.3                  29.9
# 2           2011     2011        31.8            31.8                  30.0
# 3           2011     2011        33.6            33.6                  29.9
# 4           2011     2011        32.8            32.8                  30.2
# ...          ...      ...         ...             ...                   ...
# 53382       2016     2016        13.3            13.3                   8.0
# 53383       2016     2016        25.3            25.3                  16.4
# 53384       2016     2016        18.3            18.3                  10.8
# 53385       2016     2016        24.1            24.1                  19.9
# 53386       2016     2016        30.3            30.3                  20.2
#
#        High_Confidence_Limit   Sample_Size  \
# ...
